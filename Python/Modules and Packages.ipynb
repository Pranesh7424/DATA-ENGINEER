# %% [markdown]
# # Modules and Packages

# %%
import math
print(math.pi)
# Out:
# 3.141592653589793

# %% [markdown]
# ## datetime

# %%
import datetime as dt
dt.datetime.now()
# Out:
# datetime.datetime(2026, 2, 20, 13, 3, 8, 972115)

# %% [markdown]
# ## math module

# %%
import math as m
print(m.pi)
# Out:
# 3.141592653589793

# %%
from datetime import datetime
datetime.now()
# Out:
# datetime.datetime(2026, 2, 20, 13, 3, 48, 612632)

# %%
from math import * #same
import math #same
print(math.pi)
# Out:
# 3.141592653589793
