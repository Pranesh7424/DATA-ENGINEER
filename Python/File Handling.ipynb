# %% [markdown]
# # File Handling

# %% [markdown]
# ## closing a file

# %%
lst = open(r'C:\Users\Administrator\Downloads\Data_Engineer\Python\new.txt')
lst.close()

# %%
import os
os.getenv("Home")

# %% [markdown]
# ## writing a file

# %%
import os
os.getenv('C://Users//Administrator//Downloads//Data_Engineer//Python')
lst=open("new.txt","w")
lst.write("this is 1st module \n")
lst.write("this is 2nd module")
lst.close()

# %%
lst=open("new.txt","r")
lst.read(4)
# Out:
# 'this'

# %%
lst=open("new.txt","r")
lst.read(8)
# Out:
# 'this is '

# %%
lst.tell()
# Out:
# 8

# %%
lst.seek(5)
# Out:
# 5

# %%
print(lst.read())
# Out:
# is 1st module
# this is 2nd module

# %% [markdown]
# ### read line by line using for loop

# %%
lst.seek(0)
for line in lst:
    print(line)
# Out:
# this is 1st module
#
# this is 2nd module

# %%
lst=open("new.txt","r")
lst.readline()
# Out:
# 'this is 1st module \n'

# %%
lst.readline()
# Out:
# 'this is 2nd module'

# %%
lst.readline()
# Out:
# ''

# %%
lst.seek(0)
lst.readlines()
# Out:
# ['this is 1st module \n', 'this is 2nd module']

# %% [markdown]
# ### renaming and deleting

# %%
import os
os.rename("new.txt","sample.txt")

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Administrator\\Downloads\\Data_Engineer\\Python'

# %%
os.chdir("C://Users//Administrator//Downloads//Data_Engineer//Python")

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Administrator\\Downloads\\Data_Engineer\\Python'

# %% [markdown]
# ## List of files and directory

# %%
os.listdir(os.getcwdb())
# Out:
# [b'.ipynb_checkpoints',
#  b'Assignments.ipynb',
#  b'Class.ipynb',
#  b'Error Handling.ipynb',
#  b'Functions.ipynb',
#  b'Python Practice - Dict.ipynb',
#  b'sample.txt',
#  b'Untitled.ipynb']

# %% [markdown]
# ## Create new directory

# %%
os.mkdir('Gopal')

# %%
os.listdir(os.getcwdb())
# Out:
# [b'.ipynb_checkpoints',
#  b'Assignments.ipynb',
#  b'Class.ipynb',
#  b'Error Handling.ipynb',
#  b'Functions.ipynb',
#  b'Gopal',
#  b'Python Practice - Dict.ipynb',
#  b'sample.txt',
#  b'Untitled.ipynb']
