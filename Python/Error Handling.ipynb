# %% [markdown]
# # Error Handling

# %%
dir(__builtins__)
# Out:
# ['ArithmeticError',
#  'AssertionError',
#  'AttributeError',
#  'BaseException',
#  'BaseExceptionGroup',
#  'BlockingIOError',
#  'BrokenPipeError',
#  'BufferError',
#  'BytesWarning',
#  'ChildProcessError',
#  'ConnectionAbortedError',
#  'ConnectionError',
#  'ConnectionRefusedError',
#  'ConnectionResetError',
#  'DeprecationWarning',
#  'EOFError',
#  'Ellipsis',
#  'EncodingWarning',
#  'EnvironmentError',
#  'Exception',
#  'ExceptionGroup',
#  'False',
#  'FileExistsError',
#  'FileNotFoundError',
#  'FloatingPointError',
#  'FutureWarning',
#  'GeneratorExit',
#  'IOError',
#  'ImportError',
#  'ImportWarning',
#  'IndentationError',
#  'IndexError',
#  'InterruptedError',
#  'IsADirectoryError',
#  'KeyError',
#  'KeyboardInterrupt',
#  'LookupError',
#  'MemoryError',
#  'ModuleNotFoundError',
#  'NameError',
#  'None',
#  'NotADirectoryError',
#  'NotImplemented',
#  'NotImplementedError',
#  'OSError',
#  'OverflowError',
#  'PendingDeprecationWarning',
# ...

# %% [markdown]
# ## import module sys to get the type of exception

# %%
import sys
lst = ['b',0,2]
for entry in lst:
    try:
        print("Value is:",entry)
        k= 1/int(entry)
    except:
        print("Oops",sys.exc_info(),"occured")
        print("next entry")
        print("************")
print("The reciprocal of", entry, "is", k)
# Out:
# Value is: b
# ,Oops (<class 'ValueError'>, ValueError("invalid literal for int() with base 10: 'b'"), <traceback object at 0x0000021F3B5B0A40>) occured
# ,next entry
# ,************
# ,Value is: 0
# ,Oops (<class 'ZeroDivisionError'>, ZeroDivisionError('division by zero'), <traceback object at 0x0000021F3B5B0A40>) occured
# ,next entry
# ,************
# ,Value is: 2
# ,The reciprocal of 2 is 0.5

# %%
import sys
num1=input()
num2=input()
try:
    result=int(num1)/int(num2)
except:
    print("You Have Entered a Invalid Input, Make sure it is a Integer",sys.exc_info())
# Out:
#  y
#  e
# You Have Entered a Invalid Input, Make sure it is a Integer (<class 'ValueError'>, ValueError("invalid literal for int() with base 10: 'y'"), <traceback object at 0x458a660>)

# %% [markdown]
# ## catching Specific

# %%
import sys
lst=['b',0,2]
for entry in lst:
    try:
        print("!!!!!!!!!!")
        print("Value is:",entry)
        k=1/int(entry)
    except(ValueError):
        print("This is ValueError")
    except(ZeroDivisionError):
        print("ZeroDivision Error")
    except():
        print("Other Error.")
print("The reciprocal of",entry, "is", k)
# Out:
# !!!!!!!!!!
# Value is: b
# This is ValueError
# !!!!!!!!!!
# Value is: 0
# ZeroDivision Error
# !!!!!!!!!!
# Value is: 2
# The reciprocal of 2 is 0.5

# %%
raise MemoryError("It is a Memory Error") #it shows in the console for developer to identify
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 raise MemoryError("It is a Memory Error")
#
# MemoryError: It is a Memory Error

# %%
try:
    num=int(input())
    if num<=0:
        raise ValueError("Error:Entered negative number")
except ValueError as e:
    print(e)
# Out:
#  r
# invalid literal for int() with base 10: 'r'

# %%
try:
    num=int(input("Enter a positive no."))
    if num <=0:
        raise MemoryError ("Error:RAM storage not available")
except ValueError as e:
    print(e)
# Out:
# Enter a positive no. -9
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[6], line 4
#       2     num=int(input("Enter a positive no."))
#       3     if num <=0:
# ----> 4         raise MemoryError ("Error:RAM storage not available")
#       5 except ValueError as e:
#       6     print(e)
#
# MemoryError: Error:RAM storage not available

# %%
try:
    num=int(input("Enter a positive no."))
    if num <=0:
        raise MemoryError("Error:RAM storage not available")
except MemoryError as e:
    print(e)
# Out:
# Enter a positive no. -8
# Error:RAM storage not available

# %%
import os
os.chdir('/Users/gopal/Desktop')
try:
    f = open('sample.txt')
except:
    print("File doesn't exist")
finally:
    print("final closed")
    f.close()

# %% [markdown]
# # logging

# %%
import logging
logging.basicConfig(level=logging.INFO)

logging.debug("This is a debug message")
logging.info("App started")
logging.warning("This is a warning")
logging.error("An error occured")
logging.critical("Critical issue")
# Out:
# INFO:root:App started
# ,WARNING:root:This is a warning
# ,ERROR:root:An error occured
# ,CRITICAL:root:Critical issue

# %%
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s-%(levelname)s-%(message)s'
)

# %%
logging.basicConfig(
    filename='app.log',
    level=logging.DEBUG,
    format='%(asctime)s-%(levelname)s-%(message)s'
)
